# %% [markdown]
# <a href="https://colab.research.google.com/github/kvmkrao/3DCFS/blob/master/temp_net_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://en.wikipedia.org/wiki/Thermal_expansion
#https://towardsdatascience.com/machine-learning-for-beginners-an-introduction-to-neural-networks-d49f22d238f9
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
COLUMNS =  ['Linear','Volume','Class']
FEATURES = ['Linear','Volume']
LABEL = "Class"
def get_input_fn(data_set, num_epochs=None, shuffle=True):
  return tf.compat.v1.estimator.inputs.pandas_input_fn(
      x=pd.DataFrame({k: data_set[k].values for k in FEATURES}),
      y=pd.Series(data_set[LABEL].values),
      num_epochs=num_epochs,
      shuffle=shuffle)

# %%
def sigmoid(x):
  # Sigmoid activation function: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Derivative of sigmoid: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true and y_pred are numpy arrays of the same length.
  return ((y_true - y_pred) ** 2).mean()

class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)
    The code below is intended to be simple and educational, NOT optimal.
    Real neural net code looks nothing like this.
  '''
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()

  def feedforward(self, x):
    # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1) #neuron1 in hidden layer1
    h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2) #neuron2 in hidden layer1
    o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)     ##neuron1 in output layer
    return o1

  def train(self, data, y_trues):
    '''
    - data is a (n x 2) numpy array, n = # of samples in the dataset.
    - all_y_trues is a numpy array with n elements.
      Elements in all_y_trues correspond to those in data.
    '''
    learn_rate = 0.1
    epochs = 1000 # number of times to loop through the entire dataset
    
    los = np.zeros(epochs)
    epo = np.zeros(epochs)
    for epoch in range(epochs):
      for x, y_true in zip(data, y_trues):
        # --- Do a feedforward (we'll need these values later)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = sigmoid(sum_h2)

        sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        # --- Naming: d_L_d_w1 represents "partial L / partial w1"
        dL_dy = -2 * (y_true - y_pred)

        # Neuron o1
        dy_dw5 = h1 * deriv_sigmoid(sum_o1)
        dy_dw6 = h2 * deriv_sigmoid(sum_o1)
        dy_db3 = deriv_sigmoid(sum_o1)

        dy_dh1 = self.w5 * deriv_sigmoid(sum_o1)
        dy_dh2 = self.w6 * deriv_sigmoid(sum_o1)

        # Neuron h1
        dh1_dw1 = x[0] * deriv_sigmoid(sum_h1)
        dh1_dw2 = x[1] * deriv_sigmoid(sum_h1)
        dh1_db1 = deriv_sigmoid(sum_h1)

        # Neuron h2
        dh2_dw3 = x[0] * deriv_sigmoid(sum_h2)
        dh2_dw4 = x[1] * deriv_sigmoid(sum_h2)
        dh2_db2 = deriv_sigmoid(sum_h2)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= learn_rate * dL_dy * dy_dh1 * dh1_dw1
        self.w2 -= learn_rate * dL_dy * dy_dh1 * dh1_dw2
        self.b1 -= learn_rate * dL_dy * dy_dh1 * dh1_db1

        # Neuron h2
        self.w3 -= learn_rate * dL_dy * dy_dh2 * dh2_dw3
        self.w4 -= learn_rate * dL_dy * dy_dh2 * dh2_dw4
        self.b2 -= learn_rate * dL_dy * dy_dh2 * dh2_db2

        # Neuron o1
        self.w5 -= learn_rate * dL_dy * dy_dw5
        self.w6 -= learn_rate * dL_dy * dy_dw6
        self.b3 -= learn_rate * dL_dy * dy_db3

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(y_trues, y_preds)
        #print("Epoch %d loss: %.3f" % (epoch, loss))
      los[epoch] = loss 
      epo[epoch] = epoch
    return los,epo

# %%
# Define dataset
data = np.array([
  [23.1, 69],   # Aluminium	Metal	23.1	69
  [17, 51],     # Copper	Metal	17	51
  [250, 750],   # Ethanol	Liquid	250	750
  [317, 950],   # Gasoline	Liquid	317	950[20]
  [11.8, 35.4], # Iron	Metal	11.8	35.4
  [29, 87],     # Lead	Metal	29	87\
  [13.0, 39],   # Nickel	Metal	13	39
  [69.0, 207],   #Water	Nonmetal	69	207
])

c0max = data[:,0].max()
c1max = data[:,1].max()
data[:,0] = data[:,0]/c0max
data[:,1] = data[:,1]/c1max

y_train = np.array([
  1, # Al
  1, # Cu
  0, # Ethanol
  0, # Gasoline
  1, # Iron
  1, #Lead
  1, #Nickel 
  0, #wateropti = tf.train.AdamOptimizer(learning_rate = 0.0001,epsilon=0.01)
])

# Train our neural network!
network = OurNeuralNetwork()
los, epo = network.train(data, y_train)
plt.plot(epo, los)
# Make some predictions
gold = np.array([14/c0max, 42/c1max]) # Gold	Metal	14	42
polymer = np.array([150/c0max, 450/c1max])  # Polypropylene (PP)	Polymer	150	450
print("Gold: %.3f" % network.feedforward(gold)) # metal
print("Polymer: %.3f" % network.feedforward(polymer)) # non-metal
# Out:
# Gold: 0.927
# Polymer: 0.034

# %%
# https://scikit-learn.org/stable/modules/linear_model.html
# least squres method
LR = LinearRegression()
# fitting the training data
LR.fit(data,y_train)

y_pred = LR.predict([[14/c0max, 42/c1max]])
print(y_pred)
y_pred = LR.predict([[150/c0max, 450/c1max]])
print(y_pred)
# Out:
# [0.89245946]
# [0.29439583]

# %%
input_size=2
output_size=1
models = tf.keras.Sequential([ tf.keras.layers.Dense(output_size)])
custom_optimizer=tf.keras.optimizers.Adam(learning_rate=0.01)  #SGD
models.compile(optimizer=custom_optimizer,loss='mean_squared_error')
models.fit(data,y_train,epochs=10000,verbose=0)

#weights=models.layers[0].get_weights()[0]
#bias=models.layers[0].get_weights()[1]
test_data=[[14/c0max, 42/c1max],[150/c0max, 450/c1max]]
out=models.predict(test_data)
print(out)
#test_data=[[150/c0max, 450/c1max]]
#out=models.predict(test_data)
#print(out)
# Out:
# [[0.8963485]
#  [0.4180981]]

# %%
# tensorflow 
dftrx = pd.DataFrame(data, columns=['Linear','Volume'])
dftry = pd.DataFrame(y_train, columns=['Class'])
train_set = pd.concat([dftrx, dftry], ignore_index=True, axis=1)
train_set.columns = ['Linear','Volume','Class']
print(train_set)

test_data=[[14/c0max, 42/c1max, 1],[150/c0max, 450/c1max, 0] ] 
test_set = pd.DataFrame(test_data)   #, columns=['Linear','Volume','Class'])
test_set.columns = ['Linear','Volume','Class']
print(test_set)
# Out:
#      Linear    Volume  Class
# 0  0.072871  0.072632      1
# 1  0.053628  0.053684      1
# 2  0.788644  0.789474      0
# 3  1.000000  1.000000      0
# 4  0.037224  0.037263      1
# 5  0.091483  0.091579      1
# 6  0.041009  0.041053      1
# 7  0.217666  0.217895      0
#      Linear    Volume  Class
# 0  0.044164  0.044211      1
# 1  0.473186  0.473684      0

# %%
feature_cols = [tf.feature_column.numeric_column(k) for k in FEATURES]
opti = tf.keras.optimizers.Adam(learning_rate = 0.02) #,epsilon=0.01)
regressor = tf.estimator.DNNRegressor(feature_columns=feature_cols,hidden_units=[2, 1],activation_fn=tf.nn.sigmoid, optimizer=opti)
                                      #,dropout = 0.004,optimizer=opti) 
#,model_dir='/model')
#opti.apply_gradients(zip([grad], [x]))

regressor.train(input_fn=get_input_fn(train_set),steps=10000)

prediction = regressor.predict(input_fn=get_input_fn(test_set, num_epochs=1, shuffle=False))
y_predicted = np.array(list(p['predictions'] for p in prediction))
print(abs(y_predicted))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpiyuspqs1
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpiyuspqs1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/lazy_loader.py:59: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:65: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/monitored_session.py:914: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpiyuspqs1/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.32758886, step = 0
# INFO:tensorflow:global_step/sec: 390.479
# INFO:tensorflow:loss = 0.12059122, step = 100 (0.270 sec)
# INFO:tensorflow:global_step/sec: 402.09
# INFO:tensorflow:loss = 0.038212277, step = 200 (0.237 sec)
# INFO:tensorflow:global_step/sec: 447.034
# INFO:tensorflow:loss = 0.018344555, step = 300 (0.228 sec)
# INFO:tensorflow:global_step/sec: 406.669
# INFO:tensorflow:loss = 0.017730929, step = 400 (0.247 sec)
# INFO:tensorflow:global_step/sec: 385.281
# INFO:tensorflow:loss = 0.014262711, step = 500 (0.263 sec)
# INFO:tensorflow:global_step/sec: 388.562
# INFO:tensorflow:loss = 0.018477818, step = 600 (0.255 sec)
# INFO:tensorflow:global_step/sec: 389.633
# INFO:tensorflow:loss = 0.015436479, step = 700 (0.252 sec)
# INFO:tensorflow:global_step/sec: 395.446
# INFO:tensorflow:loss = 0.013364986, step = 800 (0.255 sec)
# INFO:tensorflow:global_step/sec: 411.58
# INFO:tensorflow:loss = 0.014965974, step = 900 (0.246 sec)
# INFO:tensorflow:global_step/sec: 403.514
# INFO:tensorflow:loss = 0.0102743935, step = 1000 (0.243 sec)
# INFO:tensorflow:global_step/sec: 439.44
# INFO:tensorflow:loss = 0.0081857545, step = 1100 (0.226 sec)
# INFO:tensorflow:global_step/sec: 416.076
# INFO:tensorflow:loss = 0.007197822, step = 1200 (0.239 sec)
# INFO:tensorflow:global_step/sec: 434.202
# INFO:tensorflow:loss = 0.0046561845, step = 1300 (0.236 sec)
# INFO:tensorflow:global_step/sec: 389.515
# INFO:tensorflow:loss = 0.0035652586, step = 1400 (0.257 sec)
# INFO:tensorflow:global_step/sec: 394.022
# INFO:tensorflow:loss = 0.0031187937, step = 1500 (0.254 sec)
# INFO:tensorflow:global_step/sec: 397.44
# INFO:tensorflow:loss = 0.0026137515, step = 1600 (0.246 sec)
# INFO:tensorflow:global_step/sec: 406.799
# INFO:tensorflow:loss = 0.0019278064, step = 1700 (0.250 sec)
# INFO:tensorflow:global_step/sec: 432.395
# INFO:tensorflow:loss = 0.001596575, step = 1800 (0.232 sec)
# INFO:tensorflow:global_step/sec: 397.645
# INFO:tensorflow:loss = 0.0013179174, step = 1900 (0.249 sec)
# INFO:tensorflow:global_step/sec: 421.257
# INFO:tensorflow:loss = 0.0013050432, step = 2000 (0.239 sec)
# INFO:tensorflow:global_step/sec: 421.413
# INFO:tensorflow:loss = 0.00096010434, step = 2100 (0.242 sec)
# INFO:tensorflow:global_step/sec: 400.19
# INFO:tensorflow:loss = 0.0009344352, step = 2200 (0.249 sec)
# INFO:tensorflow:global_step/sec: 398.685
# INFO:tensorflow:loss = 0.00060550723, step = 2300 (0.253 sec)
# INFO:tensorflow:global_step/sec: 393.979
# INFO:tensorflow:loss = 0.0005844279, step = 2400 (0.248 sec)
# INFO:tensorflow:global_step/sec: 430.328
# INFO:tensorflow:loss = 0.0005992572, step = 2500 (0.230 sec)
# INFO:tensorflow:global_step/sec: 396.494
# INFO:tensorflow:loss = 0.00048411157, step = 2600 (0.251 sec)
# INFO:tensorflow:global_step/sec: 405.566
# INFO:tensorflow:loss = 0.0004576366, step = 2700 (0.247 sec)
# INFO:tensorflow:global_step/sec: 319.458
# INFO:tensorflow:loss = 0.0003644888, step = 2800 (0.312 sec)
# INFO:tensorflow:global_step/sec: 227.845
# INFO:tensorflow:loss = 0.00037069625, step = 2900 (0.442 sec)
# INFO:tensorflow:global_step/sec: 342.422
# INFO:tensorflow:loss = 0.00028703792, step = 3000 (0.295 sec)
# INFO:tensorflow:global_step/sec: 390.968
# INFO:tensorflow:loss = 0.00023455638, step = 3100 (0.255 sec)
# INFO:tensorflow:global_step/sec: 433.113
# INFO:tensorflow:loss = 0.00022696203, step = 3200 (0.229 sec)
# INFO:tensorflow:global_step/sec: 425.87
# INFO:tensorflow:loss = 0.00023276877, step = 3300 (0.237 sec)
# INFO:tensorflow:global_step/sec: 430.43
# INFO:tensorflow:loss = 0.00022210655, step = 3400 (0.233 sec)
# INFO:tensorflow:global_step/sec: 394.533
# INFO:tensorflow:loss = 0.00022326334, step = 3500 (0.257 sec)
# INFO:tensorflow:global_step/sec: 420.752
# INFO:tensorflow:loss = 0.0001833635, step = 3600 (0.233 sec)
# INFO:tensorflow:global_step/sec: 433.536
# INFO:tensorflow:loss = 0.00014874489, step = 3700 (0.226 sec)
# INFO:tensorflow:global_step/sec: 420.308
# INFO:tensorflow:loss = 0.00015760408, step = 3800 (0.243 sec)
# INFO:tensorflow:global_step/sec: 390.249
# INFO:tensorflow:loss = 0.00013350768, step = 3900 (0.256 sec)
# INFO:tensorflow:global_step/sec: 401.504
# INFO:tensorflow:loss = 0.00010287421, step = 4000 (0.250 sec)
# INFO:tensorflow:global_step/sec: 400.278
# INFO:tensorflow:loss = 0.00014184238, step = 4100 (0.251 sec)
# INFO:tensorflow:global_step/sec: 403.3
# INFO:tensorflow:loss = 9.53931e-05, step = 4200 (0.242 sec)
# INFO:tensorflow:global_step/sec: 403.593
# INFO:tensorflow:loss = 0.00010050243, step = 4300 (0.249 sec)
# INFO:tensorflow:global_step/sec: 390.515
# INFO:tensorflow:loss = 8.2838334e-05, step = 4400 (0.254 sec)
# INFO:tensorflow:global_step/sec: 387.334
# INFO:tensorflow:loss = 7.979869e-05, step = 4500 (0.263 sec)
# INFO:tensorflow:global_step/sec: 391.642
# INFO:tensorflow:loss = 9.922481e-05, step = 4600 (0.254 sec)
# INFO:tensorflow:global_step/sec: 365.568
# INFO:tensorflow:loss = 7.080872e-05, step = 4700 (0.272 sec)
# INFO:tensorflow:global_step/sec: 415.446
# INFO:tensorflow:loss = 7.123255e-05, step = 4800 (0.246 sec)
# INFO:tensorflow:global_step/sec: 404.271
# INFO:tensorflow:loss = 6.3793654e-05, step = 4900 (0.252 sec)
# INFO:tensorflow:global_step/sec: 430.383
# INFO:tensorflow:loss = 5.3839827e-05, step = 5000 (0.223 sec)
# INFO:tensorflow:global_step/sec: 395.661
# INFO:tensorflow:loss = 6.5077e-05, step = 5100 (0.249 sec)
# INFO:tensorflow:global_step/sec: 454.749
# INFO:tensorflow:loss = 5.294275e-05, step = 5200 (0.221 sec)
# INFO:tensorflow:global_step/sec: 414.99
# INFO:tensorflow:loss = 4.4657772e-05, step = 5300 (0.249 sec)
# INFO:tensorflow:global_step/sec: 396.563
# INFO:tensorflow:loss = 4.5874283e-05, step = 5400 (0.248 sec)
# INFO:tensorflow:global_step/sec: 399.236
# INFO:tensorflow:loss = 4.6560548e-05, step = 5500 (0.247 sec)
# INFO:tensorflow:global_step/sec: 421.467
# INFO:tensorflow:loss = 4.478332e-05, step = 5600 (0.236 sec)
# INFO:tensorflow:global_step/sec: 454.46
# INFO:tensorflow:loss = 3.891481e-05, step = 5700 (0.223 sec)
# INFO:tensorflow:global_step/sec: 413.847
# INFO:tensorflow:loss = 3.81779e-05, step = 5800 (0.246 sec)
# INFO:tensorflow:global_step/sec: 410.288
# INFO:tensorflow:loss = 3.3619872e-05, step = 5900 (0.239 sec)
# INFO:tensorflow:global_step/sec: 432.724
# INFO:tensorflow:loss = 3.2884327e-05, step = 6000 (0.232 sec)
# INFO:tensorflow:global_step/sec: 426.557
# INFO:tensorflow:loss = 3.9951126e-05, step = 6100 (0.234 sec)
# INFO:tensorflow:global_step/sec: 413.234
# INFO:tensorflow:loss = 2.7110636e-05, step = 6200 (0.243 sec)
# INFO:tensorflow:global_step/sec: 430.163
# INFO:tensorflow:loss = 2.4315863e-05, step = 6300 (0.234 sec)
# INFO:tensorflow:global_step/sec: 392.688
# INFO:tensorflow:loss = 2.7060443e-05, step = 6400 (0.256 sec)
# INFO:tensorflow:global_step/sec: 403.888
# INFO:tensorflow:loss = 2.7242379e-05, step = 6500 (0.244 sec)
# INFO:tensorflow:global_step/sec: 397.965
# INFO:tensorflow:loss = 2.2260881e-05, step = 6600 (0.251 sec)
# INFO:tensorflow:global_step/sec: 423.213
# INFO:tensorflow:loss = 1.9624662e-05, step = 6700 (0.236 sec)
# INFO:tensorflow:global_step/sec: 419.076
# INFO:tensorflow:loss = 3.2609085e-05, step = 6800 (0.238 sec)
# INFO:tensorflow:global_step/sec: 384.417
# INFO:tensorflow:loss = 2.1796048e-05, step = 6900 (0.261 sec)
# INFO:tensorflow:global_step/sec: 448.871
# INFO:tensorflow:loss = 1.6864207e-05, step = 7000 (0.219 sec)
# INFO:tensorflow:global_step/sec: 439.78
# INFO:tensorflow:loss = 1.6250453e-05, step = 7100 (0.237 sec)
# INFO:tensorflow:global_step/sec: 399.638
# INFO:tensorflow:loss = 1.7897713e-05, step = 7200 (0.244 sec)
# INFO:tensorflow:global_step/sec: 408.674
# INFO:tensorflow:loss = 1.7592616e-05, step = 7300 (0.247 sec)
# INFO:tensorflow:global_step/sec: 443.13
# INFO:tensorflow:loss = 1.943784e-05, step = 7400 (0.221 sec)
# INFO:tensorflow:global_step/sec: 401.833
# INFO:tensorflow:loss = 1.3125815e-05, step = 7500 (0.250 sec)
# INFO:tensorflow:global_step/sec: 395.189
# INFO:tensorflow:loss = 1.30991275e-05, step = 7600 (0.255 sec)
# INFO:tensorflow:global_step/sec: 409.821
# INFO:tensorflow:loss = 1.2640332e-05, step = 7700 (0.246 sec)
# INFO:tensorflow:global_step/sec: 417.157
# INFO:tensorflow:loss = 1.32071345e-05, step = 7800 (0.237 sec)
# INFO:tensorflow:global_step/sec: 385.294
# INFO:tensorflow:loss = 9.1775e-06, step = 7900 (0.259 sec)
# INFO:tensorflow:global_step/sec: 401.604
# INFO:tensorflow:loss = 1.5704232e-05, step = 8000 (0.247 sec)
# INFO:tensorflow:global_step/sec: 396.485
# INFO:tensorflow:loss = 9.542035e-06, step = 8100 (0.252 sec)
# INFO:tensorflow:global_step/sec: 400.507
# INFO:tensorflow:loss = 9.300533e-06, step = 8200 (0.254 sec)
# INFO:tensorflow:global_step/sec: 411.488
# INFO:tensorflow:loss = 8.855522e-06, step = 8300 (0.243 sec)
# INFO:tensorflow:global_step/sec: 406.894
# INFO:tensorflow:loss = 7.9530655e-06, step = 8400 (0.243 sec)
# INFO:tensorflow:global_step/sec: 355.388
# INFO:tensorflow:loss = 8.285278e-06, step = 8500 (0.284 sec)
# INFO:tensorflow:global_step/sec: 326.216
# INFO:tensorflow:loss = 6.7730844e-06, step = 8600 (0.303 sec)
# INFO:tensorflow:global_step/sec: 424.628
# INFO:tensorflow:loss = 7.63103e-06, step = 8700 (0.233 sec)
# INFO:tensorflow:global_step/sec: 367.332
# INFO:tensorflow:loss = 7.673103e-06, step = 8800 (0.274 sec)
# INFO:tensorflow:global_step/sec: 305.314
# INFO:tensorflow:loss = 9.068612e-06, step = 8900 (0.330 sec)
# INFO:tensorflow:global_step/sec: 246.465
# INFO:tensorflow:loss = 5.0285653e-06, step = 9000 (0.407 sec)
# INFO:tensorflow:global_step/sec: 219.397
# INFO:tensorflow:loss = 5.6265744e-06, step = 9100 (0.452 sec)
# INFO:tensorflow:global_step/sec: 295.991
# INFO:tensorflow:loss = 8.33631e-06, step = 9200 (0.335 sec)
# INFO:tensorflow:global_step/sec: 214.51
# INFO:tensorflow:loss = 5.1661264e-06, step = 9300 (0.466 sec)
# INFO:tensorflow:global_step/sec: 196.162
# INFO:tensorflow:loss = 4.8725487e-06, step = 9400 (0.521 sec)
# INFO:tensorflow:global_step/sec: 212.571
# INFO:tensorflow:loss = 4.1366548e-06, step = 9500 (0.466 sec)
# INFO:tensorflow:global_step/sec: 187.887
# INFO:tensorflow:loss = 4.2630163e-06, step = 9600 (0.531 sec)
# INFO:tensorflow:global_step/sec: 231.144
# INFO:tensorflow:loss = 4.1125477e-06, step = 9700 (0.436 sec)
# INFO:tensorflow:global_step/sec: 229.453
# INFO:tensorflow:loss = 5.128643e-06, step = 9800 (0.428 sec)
# INFO:tensorflow:global_step/sec: 264.075
# INFO:tensorflow:loss = 3.225538e-06, step = 9900 (0.385 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmpiyuspqs1/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Loss for final step: 3.2776202e-06.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpiyuspqs1/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [[0.9994079 ]
#  [0.00279798]]

# %%
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 6 decision trees
rf = RandomForestRegressor(n_estimators =8,random_state = 10)
# Train the model on training data
model = rf.fit(data,y_train)
# test data 
test_data = [[14/c0max, 42/c1max],[150/c0max, 450/c1max]]
# predict 
y_pred = model.predict(test_data)  # test the output by changing values
print(y_pred)
# Out:
# [1.   0.25]

# %%
z = np.polyfit(data[:,0], y_train, 3)
z1 = np.polyfit(data[:,1], y_train, 3)
zf = np.polyfit(z, z1, 3)
